# %%
# !python strotss_guided.py content_im.jpg style_im.jpg --content_mask content_guidance.jpg --style_mask style_guidance.jpeg  --output output.png
# Out:
# /home/exouser/anaconda3/envs/singan/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/exouser/anaconda3/envs/singan/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Optimizing at resoluton [42, 64]
# Style: 2.331, Content: 0.027
# Style: 3.206, Content: 0.038
# Style: 2.223, Content: 0.064
# Style: 2.460, Content: 0.054
# Style: 2.233, Content: 0.095
# Style: 2.131, Content: 0.043
# Style: 3.017, Content: 0.060
# Style: 2.159, Content: 0.026
# Style: 2.280, Content: 0.059
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace 'your_image.png' with the path to your image file
image = Image.open('style_im.jpg')

plt.imshow(image)
plt.axis('off')  # This turns off the axis numbers
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace 'your_image.png' with the path to your image file
image = Image.open('content_im.jpg')

plt.imshow(image)
plt.axis('off')  # This turns off the axis numbers
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace 'your_image.png' with the path to your image file
image = Image.open('output.png')

plt.imshow(image)
plt.axis('off')  # This turns off the axis numbers
plt.show()
